# %%
number1 = 22
number2 = 22

if number1 == number2:
    print("Numbers are equal")
else:
    print("Numbers are not equal")
    
    
if number1 > number2:
    print("Number1 is greater than number2")
else:
    print("Number1 is not greater than number2")
    

if number1 >= number2:
    print("Number1 is equal to or greater than number2")
else:
    print("Number1 is smaller than number2")
    

if number1 != number2:
    print("Numbers are not equal")
else:
    print("Numbers are equal")
    
    
    
number1 = 1
number2 = 2
number3 = 1


if number1 == number2 == number3:
    print("Numbers are equal")
else:
    print("Numbers are not equal")
    
    
if number1 == number2 or number2 == number3:
    print("Numbers 1 and 2 and/or numbers 2 and 3 are equal")
    

if number1 > number2 and number1 > number3:
    print("Number1 is greater than number2 and number1 is greater than number3")


if number1 > number2:
    print("Number1 is greater than number2")
elif number2 > number3:
    print("Number2 is greater than number3")


if number1 == number2:
    print("Number1 and number2 are equal")
elif number1 == number3:
    print("Number1 and number3 are equal")



name1 = "Marko"
name2 = "Jossu"
name3 = "Marko"

if name1 == name2:
    print("Name1 and name2 are equal")
    
    
if name1 != name2:
    print("Name1 and name2 are not equal")
    
    
if name1 == name2:
    print("Name1 and name2 are equal")
elif name1 == name3:
    print("Name1 and name3 are equal")
# Out:
# Numbers are equal
# Number1 is not greater than number2
# Number1 is equal to or greater than number2
# Numbers are equal
# Numbers are not equal
# Number2 is greater than number3
# Number1 and number3 are equal
# Name1 and name2 are not equal
# Name1 and name3 are equal
